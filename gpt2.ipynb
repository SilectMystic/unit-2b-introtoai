# %%
import gpt_2_simple as gpt2

# %%
# gpt2.download_gpt2(model_name='124M')

# %%
session = gpt2.start_tf_sess()

# %%
gpt2.finetune(session, 'shakespeare.txt', model_name='124M', steps=5)
# Out:
# 2023-12-14 10:06:10.272641: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# Loading checkpoint checkpoint/run1/model-9
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-9
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# dataset has 338024 tokens
# Training...
# [10 | 15.76] loss=3.75 avg=3.75
# [11 | 29.80] loss=3.81 avg=3.78
# [12 | 43.83] loss=3.69 avg=3.75
# [13 | 57.75] loss=3.74 avg=3.75
# [14 | 71.70] loss=3.52 avg=3.70
# Saving checkpoint/run1/model-14

# %%
gpt2.generate(session, prefix='Javier: No no square')
# Out:
# Javier: No no square area for a counter.
#
# Javier: Have you seen the painter's face?
#
# Lassie:
#
# Javier: I tell you, he is a man who had a vision of his own.
#
# Lassie:
# Yes, of course.
#
# Javier: Come, let me order you.
#
# Lassie:
# I have a reason.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not, I will not.
#
# Javier:
#
# Lassie:
# If you are not,
